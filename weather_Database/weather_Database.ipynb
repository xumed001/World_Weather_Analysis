# %%
# imports 

import pandas as pd
import numpy as np
from citipy import citipy

import requests
from datetime import datetime
from config import weather_api_key

# %%
# generate 2,000 random lat/lng 

lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)

lats_lngs = zip(lats, lngs)
lats_lngs

# turn it into a list
coord = list(lats_lngs)

# %%
# to store all the cities
cities = []

# Identify the nearest city (citiPy)
for items in coord:
    city = citipy.nearest_city(items[0], items[1]).city_name
    
    # if the city name is unique add it to cities list
    if city not in cities:
        cities.append(city)
        
# print to check 
len(cities)
# Out:
# 745

# %%
# url for API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# retrieve weather information from the Api and store it #
# empty list to hold weather data
city_data = []

# print statements to indicate script starting
print("Beginning Data Retrieval")
print("------------------------------------------------------------------")

# counters for dividing large data of cities to set of 50 and counting it 
record_count = 1 
set_count = 1

# loop throught all cities in the list
for i, city in enumerate(cities):
    
    # group cities in set of 50
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
    
    # endpoint Url and removing spaces 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record and set the numbers and the city.
    print(f"Processing record {record_count} of set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    ## Run API requests for each city ##
    try:
        city_weather = requests.get(city_url).json() # Parse the JSON and retrieve data.
        # Parse out the required data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_maxtemp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_d = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # append the city info into city data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_maxtemp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_d})
        
    # if error is experienced print skip message    
    except:
        print("City not found... Skipping.")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------------------------------------------
# Processing record 1 of set 1 | atuona
# Processing record 2 of set 1 | pakxan
# Processing record 3 of set 1 | sao filipe
# Processing record 4 of set 1 | jujuy
# City not found... Skipping.
# Processing record 5 of set 1 | huichapan
# Processing record 6 of set 1 | khatanga
# Processing record 7 of set 1 | albany
# Processing record 8 of set 1 | busselton
# Processing record 9 of set 1 | tatarskaya kargala
# Processing record 10 of set 1 | rikitea
# Processing record 11 of set 1 | balkhash
# Processing record 12 of set 1 | jiddah
# City not found... Skipping.
# Processing record 13 of set 1 | waipawa
# Processing record 14 of set 1 | hithadhoo
# Processing record 15 of set 1 | mashhad
# Processing record 16 of set 1 | iqaluit
# Processing record 17 of set 1 | bambous virieux
# Processing record 18 of set 1 | marawi
# Processing record 19 of set 1 | kapaa
# Processing record 20 of set 1 | taolanaro
# City not found... Skipping.
# Processing record 21 of set 1 | moratuwa
# Processing record 22 of set 1 | bunia
# Processing record 23 of set 1 | mentok
# City not found... Skipping.
# Processing record 24 of set 1 | williston
# Processing record 25 of set 1 | tuatapere
# Processing record 26 of set 1 | namibe
# Processing record 27 of set 1 | castro
# Processing record 28 of set 1 | xining
# Processing record 29 of set 1 | yar-sale
# Processing record 30 of set 1 | tasiilaq
# Processing record 31 of set 1 | butaritari
# Processing record 32 of set 1 | punta arenas
# Processing record 33 of set 1 | ushuaia
# Processing record 34 of set 1 | klaeng
# Processing record 35 of set 1 | taua
# Processing record 36 of set 1 | yellowknife
# Processing record 37 of set 1 | tiksi
# Processing record 38 of set 1 | chuy
# Processing record 39 of set 1 | bluff
# Processing record 40 of set 1 | sitka
# Processing record 41 of set 1 | upernavik
# Processing record 42 of set 1 | vaini
# Processing record 43 of set 1 | hamilton
# Processing record 44 of set 1 | hobart
# Processing record 45 of set 1 | xai-xai
# Processing record 46 of set 1 | kavieng
# Processing record 47 of set 1 | new norfolk
# Processing record 48 of set 1 | lorengau
# Processing record 49 of set 1 | turukhansk
# Processing record 50 of set 1 | christchurch
# Processing record 52 of set 2 | hermanus
# Processing record 53 of set 2 | yarmouth
# Processing record 54 of set 2 | severodvinsk
# Processing record 55 of set 2 | kahului
# Processing record 56 of set 2 | omsukchan
# Processing record 57 of set 2 | samusu
# City not found... Skipping.
# Processing record 58 of set 2 | galgani
# City not found... Skipping.
# Processing record 59 of set 2 | oulainen
# Processing record 60 of set 2 | olafsvik
# Processing record 61 of set 2 | richards bay
# Processing record 62 of set 2 | tateyama
# Processing record 63 of set 2 | vredendal
# Processing record 64 of set 2 | port said
# Processing record 65 of set 2 | avarua
# Processing record 66 of set 2 | fernie
# Processing record 67 of set 2 | ribeira grande
# Processing record 68 of set 2 | tolaga bay
# Processing record 69 of set 2 | farafangana
# Processing record 70 of set 2 | lukovetskiy
# Processing record 71 of set 2 | lavrentiya
# Processing record 72 of set 2 | carnarvon
# Processing record 73 of set 2 | coihaique
# Processing record 74 of set 2 | ancud
# Processing record 75 of set 2 | rudbar
# Processing record 76 of set 2 | rawson
# Processing record 77 of set 2 | mlandizi
# Processing record 78 of set 2 | soni
# Processing record 79 of set 2 | mataura
# Processing record 80 of set 2 | kodiak
# Processing record 81 of set 2 | phuthaditjhaba
# Processing record 82 of set 2 | hornepayne
# Processing record 83 of set 2 | cape town
# Processing record 84 of set 2 | victoria
# Processing record 85 of set 2 | bengkulu
# Processing record 86 of set 2 | cockburn town
# Processing record 87 of set 2 | goderich
# Processing record 88 of set 2 | portland
# Processing record 89 of set 2 | east london
# Processing record 90 of set 2 | ust-kamchatsk
# City not found... Skipping.
# Processing record 91 of set 2 | shingu
# Processing record 92 of set 2 | lagoa
# Processing record 93 of set 2 | whitecourt
# Processing record 94 of set 2 | linxia
# Processing record 95 of set 2 | jamestown
# Processing record 96 of set 2 | illoqqortoormiut
# City not found... Skipping.
# Processing record 97 of set 2 | kisesa
# Processing record 98 of set 2 | barrow
# Processing record 99 of set 2 | labuhan
# Processing record 100 of set 2 | fairbanks
# Processing record 101 of set 2 | puksoozero
# Processing record 103 of set 3 | nadym
# Processing record 104 of set 3 | bairiki
# Processing record 105 of set 3 | paragominas
# Processing record 106 of set 3 | port alfred
# Processing record 107 of set 3 | kaniama
# Processing record 108 of set 3 | port elizabeth
# Processing record 109 of set 3 | clyde river
# Processing record 110 of set 3 | mar del plata
# Processing record 111 of set 3 | tazovskiy
# Processing record 112 of set 3 | bethel
# Processing record 113 of set 3 | marystown
# Processing record 114 of set 3 | norman wells
# Processing record 115 of set 3 | anaco
# Processing record 116 of set 3 | mae sai
# Processing record 117 of set 3 | edgewater
# Processing record 118 of set 3 | talnakh
# Processing record 119 of set 3 | katsuura
# Processing record 120 of set 3 | nanortalik
# Processing record 121 of set 3 | kamaishi
# Processing record 122 of set 3 | burnie
# Processing record 123 of set 3 | bambanglipuro
# Processing record 124 of set 3 | kaitangata
# Processing record 125 of set 3 | severnyy
# Processing record 126 of set 3 | nuuk
# Processing record 127 of set 3 | aswan
# Processing record 128 of set 3 | yuzhno-yeniseyskiy
# City not found... Skipping.
# Processing record 129 of set 3 | nishihara
# Processing record 130 of set 3 | mehran
# Processing record 131 of set 3 | poso
# Processing record 132 of set 3 | farmington
# Processing record 133 of set 3 | celestun
# Processing record 134 of set 3 | mahebourg
# Processing record 135 of set 3 | ugoofaaru
# Processing record 136 of set 3 | pevek
# Processing record 137 of set 3 | faanui
# Processing record 138 of set 3 | isiro
# Processing record 139 of set 3 | beringovskiy
# Processing record 140 of set 3 | bredasdorp
# Processing record 141 of set 3 | quatre cocos
# Processing record 142 of set 3 | nelson bay
# Processing record 143 of set 3 | paamiut
# Processing record 144 of set 3 | attawapiskat
# City not found... Skipping.
# Processing record 145 of set 3 | tuktoyaktuk
# Processing record 146 of set 3 | muncar
# Processing record 147 of set 3 | zaoyang
# Processing record 148 of set 3 | peniche
# Processing record 149 of set 3 | bardiyah
# Processing record 150 of set 3 | asau
# Processing record 151 of set 3 | coquimbo
# Processing record 152 of set 3 | fortuna
# Processing record 154 of set 4 | boma
# Processing record 155 of set 4 | yueyang
# Processing record 156 of set 4 | vigrestad
# Processing record 157 of set 4 | bagua grande
# Processing record 158 of set 4 | pisco
# Processing record 159 of set 4 | ust-ishim
# Processing record 160 of set 4 | kudahuvadhoo
# Processing record 161 of set 4 | peddapalli
# Processing record 162 of set 4 | husavik
# Processing record 163 of set 4 | san quintin
# Processing record 164 of set 4 | banjar
# Processing record 165 of set 4 | mount gambier
# Processing record 166 of set 4 | chokurdakh
# Processing record 167 of set 4 | manaus
# Processing record 168 of set 4 | dikson
# Processing record 169 of set 4 | kattivakkam
# Processing record 170 of set 4 | rocha
# Processing record 171 of set 4 | longyearbyen
# Processing record 172 of set 4 | sorvag
# City not found... Skipping.
# Processing record 173 of set 4 | mattru
# Processing record 174 of set 4 | amalapuram
# Processing record 175 of set 4 | artyk
# City not found... Skipping.
# Processing record 176 of set 4 | baghmara
# Processing record 177 of set 4 | qandahar
# City not found... Skipping.
# Processing record 178 of set 4 | caravelas
# Processing record 179 of set 4 | caorle
# Processing record 180 of set 4 | vardo
# Processing record 181 of set 4 | bereda
# Processing record 182 of set 4 | madona
# Processing record 183 of set 4 | yulara
# Processing record 184 of set 4 | kailua
# Processing record 185 of set 4 | malatya
# Processing record 186 of set 4 | berlevag
# Processing record 187 of set 4 | torbay
# Processing record 188 of set 4 | bodden town
# Processing record 189 of set 4 | malinyi
# Processing record 190 of set 4 | kasongo-lunda
# Processing record 191 of set 4 | khvastovichi
# Processing record 192 of set 4 | san jose
# Processing record 193 of set 4 | hasaki
# Processing record 194 of set 4 | tir pol
# City not found... Skipping.
# Processing record 195 of set 4 | mujiayingzi
# Processing record 196 of set 4 | we
# City not found... Skipping.
# Processing record 197 of set 4 | laguna
# Processing record 198 of set 4 | texarkana
# Processing record 199 of set 4 | morant bay
# Processing record 200 of set 4 | shenjiamen
# Processing record 201 of set 4 | kavaratti
# Processing record 202 of set 4 | port moresby
# Processing record 203 of set 4 | obo
# Processing record 205 of set 5 | skjervoy
# Processing record 206 of set 5 | bom jardim
# Processing record 207 of set 5 | broome
# Processing record 208 of set 5 | diamantino
# Processing record 209 of set 5 | kruisfontein
# Processing record 210 of set 5 | puerto ayora
# Processing record 211 of set 5 | hilo
# Processing record 212 of set 5 | saint-joseph
# Processing record 213 of set 5 | constitucion
# Processing record 214 of set 5 | mogadishu
# Processing record 215 of set 5 | bindura
# Processing record 216 of set 5 | ginda
# Processing record 217 of set 5 | vestmannaeyjar
# Processing record 218 of set 5 | umm kaddadah
# Processing record 219 of set 5 | aklavik
# Processing record 220 of set 5 | guerrero negro
# Processing record 221 of set 5 | vao
# Processing record 222 of set 5 | necochea
# Processing record 223 of set 5 | port blair
# Processing record 224 of set 5 | maragogi
# Processing record 225 of set 5 | hanau
# Processing record 226 of set 5 | kannur
# Processing record 227 of set 5 | luis correia
# Processing record 228 of set 5 | amderma
# City not found... Skipping.
# Processing record 229 of set 5 | hualmay
# Processing record 230 of set 5 | mercedes
# Processing record 231 of set 5 | scarborough
# Processing record 232 of set 5 | garachine
# Processing record 233 of set 5 | half moon bay
# Processing record 234 of set 5 | kawalu
# Processing record 235 of set 5 | ust-nera
# Processing record 236 of set 5 | san carlos
# Processing record 237 of set 5 | dudinka
# Processing record 238 of set 5 | los llanos de aridane
# Processing record 239 of set 5 | chagda
# City not found... Skipping.
# Processing record 240 of set 5 | saskylakh
# Processing record 241 of set 5 | belushya guba
# City not found... Skipping.
# Processing record 242 of set 5 | cidreira
# Processing record 243 of set 5 | bilibino
# Processing record 244 of set 5 | cherskiy
# Processing record 245 of set 5 | evensk
# Processing record 246 of set 5 | lompoc
# Processing record 247 of set 5 | kununurra
# Processing record 248 of set 5 | naze
# Processing record 249 of set 5 | huicheng
# Processing record 250 of set 5 | wulanhaote
# City not found... Skipping.
# Processing record 251 of set 5 | teguise
# Processing record 252 of set 5 | tilichiki
# Processing record 253 of set 5 | ahuimanu
# Processing record 254 of set 5 | lakes entrance
# Processing record 256 of set 6 | oyama
# Processing record 257 of set 6 | razdolnoye
# Processing record 258 of set 6 | batemans bay
# Processing record 259 of set 6 | northam
# Processing record 260 of set 6 | henties bay
# Processing record 261 of set 6 | kholodnyy
# Processing record 262 of set 6 | nikolskoye
# Processing record 263 of set 6 | promyshlennyy
# Processing record 264 of set 6 | thompson
# Processing record 265 of set 6 | saint anthony
# Processing record 266 of set 6 | hue
# Processing record 267 of set 6 | fort nelson
# Processing record 268 of set 6 | alice springs
# Processing record 269 of set 6 | santol
# Processing record 270 of set 6 | lensk
# Processing record 271 of set 6 | koindu
# Processing record 272 of set 6 | ngukurr
# City not found... Skipping.
# Processing record 273 of set 6 | petropavlovsk-kamchatskiy
# Processing record 274 of set 6 | hofn
# Processing record 275 of set 6 | dongying
# Processing record 276 of set 6 | ulsteinvik
# Processing record 277 of set 6 | terrace
# Processing record 278 of set 6 | yaan
# Processing record 279 of set 6 | pacific grove
# Processing record 280 of set 6 | tarudant
# City not found... Skipping.
# Processing record 281 of set 6 | bagepalli
# Processing record 282 of set 6 | auki
# Processing record 283 of set 6 | iralaya
# Processing record 284 of set 6 | nouakchott
# Processing record 285 of set 6 | georgetown
# Processing record 286 of set 6 | kristiinankaupunki
# Processing record 287 of set 6 | the valley
# Processing record 288 of set 6 | mount isa
# Processing record 289 of set 6 | bubaque
# Processing record 290 of set 6 | salto
# Processing record 291 of set 6 | cabo san lucas
# Processing record 292 of set 6 | tual
# Processing record 293 of set 6 | abha
# Processing record 294 of set 6 | esperance
# Processing record 295 of set 6 | kutum
# Processing record 296 of set 6 | port-cartier
# Processing record 297 of set 6 | hambantota
# Processing record 298 of set 6 | saint-philippe
# Processing record 299 of set 6 | taos
# Processing record 300 of set 6 | barentsburg
# City not found... Skipping.
# Processing record 301 of set 6 | geraldton
# Processing record 302 of set 6 | flin flon
# Processing record 303 of set 6 | boa vista
# Processing record 304 of set 6 | bermeo
# Processing record 305 of set 6 | brae
# Processing record 307 of set 7 | rio tercero
# Processing record 308 of set 7 | mandalgovi
# Processing record 309 of set 7 | sistranda
# Processing record 310 of set 7 | nizhneyansk
# City not found... Skipping.
# Processing record 311 of set 7 | mnogovershinnyy
# Processing record 312 of set 7 | provideniya
# Processing record 313 of set 7 | port lincoln
# Processing record 314 of set 7 | coahuayana
# Processing record 315 of set 7 | micheweni
# Processing record 316 of set 7 | rapid valley
# Processing record 317 of set 7 | arraial do cabo
# Processing record 318 of set 7 | airai
# Processing record 319 of set 7 | paita
# Processing record 320 of set 7 | pietersburg
# Processing record 321 of set 7 | litoral del san juan
# City not found... Skipping.
# Processing record 322 of set 7 | jinchang
# Processing record 323 of set 7 | tura
# Processing record 324 of set 7 | kargasok
# Processing record 325 of set 7 | kamenskoye
# City not found... Skipping.
# Processing record 326 of set 7 | salalah
# Processing record 327 of set 7 | margate
# Processing record 328 of set 7 | sozimskiy
# Processing record 329 of set 7 | zheleznodorozhnyy
# Processing record 330 of set 7 | bud
# Processing record 331 of set 7 | san pedro de macoris
# Processing record 332 of set 7 | kyra
# Processing record 333 of set 7 | tautira
# Processing record 334 of set 7 | alenquer
# Processing record 335 of set 7 | mayumba
# Processing record 336 of set 7 | uwayl
# City not found... Skipping.
# Processing record 337 of set 7 | salta
# Processing record 338 of set 7 | ruatoria
# City not found... Skipping.
# Processing record 339 of set 7 | maputo
# Processing record 340 of set 7 | huai thalaeng
# Processing record 341 of set 7 | aksu
# Processing record 342 of set 7 | sorland
# Processing record 343 of set 7 | mananjary
# Processing record 344 of set 7 | buala
# Processing record 345 of set 7 | chongwe
# Processing record 346 of set 7 | kangaatsiaq
# Processing record 347 of set 7 | savannah bight
# Processing record 348 of set 7 | pinheiro
# Processing record 349 of set 7 | catamarca
# Processing record 350 of set 7 | tarauaca
# Processing record 351 of set 7 | biak
# Processing record 352 of set 7 | pierre
# Processing record 353 of set 7 | craigieburn
# Processing record 354 of set 7 | san policarpo
# Processing record 355 of set 7 | dien bien
# City not found... Skipping.
# Processing record 356 of set 7 | westport
# Processing record 358 of set 8 | palmer
# Processing record 359 of set 8 | xiaoshi
# Processing record 360 of set 8 | makakilo city
# Processing record 361 of set 8 | qaanaaq
# Processing record 362 of set 8 | san patricio
# Processing record 363 of set 8 | ust-tsilma
# Processing record 364 of set 8 | marsh harbour
# Processing record 365 of set 8 | haines junction
# Processing record 366 of set 8 | mys shmidta
# City not found... Skipping.
# Processing record 367 of set 8 | atar
# Processing record 368 of set 8 | whitehorse
# Processing record 369 of set 8 | ambilobe
# Processing record 370 of set 8 | greystones
# Processing record 371 of set 8 | tahta
# Processing record 372 of set 8 | souillac
# Processing record 373 of set 8 | sauce
# Processing record 374 of set 8 | sangar
# Processing record 375 of set 8 | smirnykh
# Processing record 376 of set 8 | nenjiang
# Processing record 377 of set 8 | faya
# Processing record 378 of set 8 | saint george
# Processing record 379 of set 8 | batagay-alyta
# Processing record 380 of set 8 | ust-kulom
# Processing record 381 of set 8 | kalabo
# Processing record 382 of set 8 | severo-kurilsk
# Processing record 383 of set 8 | ituni
# City not found... Skipping.
# Processing record 384 of set 8 | ostrovnoy
# Processing record 385 of set 8 | ilo
# Processing record 386 of set 8 | lolua
# City not found... Skipping.
# Processing record 387 of set 8 | ketchikan
# Processing record 388 of set 8 | honiara
# Processing record 389 of set 8 | sabang
# Processing record 390 of set 8 | namatanai
# Processing record 391 of set 8 | birao
# Processing record 392 of set 8 | eureka
# Processing record 393 of set 8 | dzhida
# Processing record 394 of set 8 | iturama
# Processing record 395 of set 8 | santa vitoria do palmar
# Processing record 396 of set 8 | jumla
# Processing record 397 of set 8 | ler
# Processing record 398 of set 8 | touros
# Processing record 399 of set 8 | kanniyakumari
# Processing record 400 of set 8 | ilulissat
# Processing record 401 of set 8 | aquiraz
# Processing record 402 of set 8 | salinas
# Processing record 403 of set 8 | buraydah
# Processing record 404 of set 8 | bella union
# Processing record 405 of set 8 | sompeta
# Processing record 406 of set 8 | kouroussa
# Processing record 407 of set 8 | udachnyy
# Processing record 409 of set 9 | inverell
# Processing record 410 of set 9 | bhikhi
# Processing record 411 of set 9 | ballina
# Processing record 412 of set 9 | bilma
# Processing record 413 of set 9 | vucje
# Processing record 414 of set 9 | grand river south east
# City not found... Skipping.
# Processing record 415 of set 9 | hajipur
# Processing record 416 of set 9 | adeje
# Processing record 417 of set 9 | tsihombe
# City not found... Skipping.
# Processing record 418 of set 9 | palauig
# Processing record 419 of set 9 | novyy starodub
# Processing record 420 of set 9 | rodney
# Processing record 421 of set 9 | agadir
# Processing record 422 of set 9 | tevriz
# Processing record 423 of set 9 | sentyabrskiy
# City not found... Skipping.
# Processing record 424 of set 9 | fairlie
# Processing record 425 of set 9 | talaya
# Processing record 426 of set 9 | green river
# Processing record 427 of set 9 | moose factory
# Processing record 428 of set 9 | hobyo
# Processing record 429 of set 9 | shahe
# Processing record 430 of set 9 | kota kinabalu
# Processing record 431 of set 9 | munxar
# Processing record 432 of set 9 | saleaula
# City not found... Skipping.
# Processing record 433 of set 9 | vila velha
# Processing record 434 of set 9 | ust-uda
# Processing record 435 of set 9 | vaitupu
# City not found... Skipping.
# Processing record 436 of set 9 | san carlos de bariloche
# Processing record 437 of set 9 | rusape
# Processing record 438 of set 9 | bonthe
# Processing record 439 of set 9 | meulaboh
# Processing record 440 of set 9 | mareeba
# Processing record 441 of set 9 | asyut
# Processing record 442 of set 9 | ahipara
# Processing record 443 of set 9 | makinsk
# Processing record 444 of set 9 | bosaso
# Processing record 445 of set 9 | canoa
# Processing record 446 of set 9 | labe
# Processing record 447 of set 9 | dumka
# Processing record 448 of set 9 | lityn
# Processing record 449 of set 9 | comodoro rivadavia
# Processing record 450 of set 9 | sogdiondon
# City not found... Skipping.
# Processing record 451 of set 9 | kieta
# Processing record 452 of set 9 | yagodnoye
# Processing record 453 of set 9 | susanville
# Processing record 454 of set 9 | kushima
# Processing record 455 of set 9 | gorontalo
# Processing record 456 of set 9 | ardahan
# Processing record 457 of set 9 | broken hill
# Processing record 458 of set 9 | hutang
# Processing record 460 of set 10 | sur
# Processing record 461 of set 10 | usinsk
# Processing record 462 of set 10 | korla
# Processing record 463 of set 10 | avera
# Processing record 464 of set 10 | lusambo
# Processing record 465 of set 10 | cabedelo
# Processing record 466 of set 10 | tolstoy-yurt
# Processing record 467 of set 10 | dzaoudzi
# Processing record 468 of set 10 | luderitz
# Processing record 469 of set 10 | tiarei
# Processing record 470 of set 10 | turbat
# Processing record 471 of set 10 | beypur
# City not found... Skipping.
# Processing record 472 of set 10 | sfantu gheorghe
# Processing record 473 of set 10 | pringsewu
# Processing record 474 of set 10 | nantucket
# Processing record 475 of set 10 | dutse
# Processing record 476 of set 10 | colwyn bay
# Processing record 477 of set 10 | carmo do paranaiba
# Processing record 478 of set 10 | martinsville
# Processing record 479 of set 10 | moshny
# Processing record 480 of set 10 | ayagoz
# Processing record 481 of set 10 | mana
# Processing record 482 of set 10 | bulancak
# Processing record 483 of set 10 | kuching
# Processing record 484 of set 10 | srednekolymsk
# Processing record 485 of set 10 | krasnyy chikoy
# Processing record 486 of set 10 | zilair
# Processing record 487 of set 10 | severobaykalsk
# Processing record 488 of set 10 | santa cruz
# Processing record 489 of set 10 | velikodvorskiy
# Processing record 490 of set 10 | alofi
# Processing record 491 of set 10 | nizhniy kuranakh
# Processing record 492 of set 10 | ust-omchug
# Processing record 493 of set 10 | guerrero
# Processing record 494 of set 10 | grand gaube
# Processing record 495 of set 10 | dawei
# Processing record 496 of set 10 | alta floresta
# Processing record 497 of set 10 | grand centre
# City not found... Skipping.
# Processing record 498 of set 10 | mackay
# Processing record 499 of set 10 | cayenne
# Processing record 500 of set 10 | nome
# Processing record 501 of set 10 | saldanha
# Processing record 502 of set 10 | banda aceh
# Processing record 503 of set 10 | kulhudhuffushi
# Processing record 504 of set 10 | ambagarh chauki
# Processing record 505 of set 10 | matay
# Processing record 506 of set 10 | morristown
# Processing record 507 of set 10 | durazno
# Processing record 508 of set 10 | phan thiet
# Processing record 509 of set 10 | narsaq
# Processing record 511 of set 11 | atambua
# Processing record 512 of set 11 | tumannyy
# City not found... Skipping.
# Processing record 513 of set 11 | shellbrook
# Processing record 514 of set 11 | sokoni
# Processing record 515 of set 11 | cabatuan
# Processing record 516 of set 11 | altamont
# Processing record 517 of set 11 | morondava
# Processing record 518 of set 11 | astoria
# Processing record 519 of set 11 | luena
# Processing record 520 of set 11 | abu kamal
# Processing record 521 of set 11 | cherlak
# Processing record 522 of set 11 | noumea
# Processing record 523 of set 11 | kondinskoye
# Processing record 524 of set 11 | malwan
# City not found... Skipping.
# Processing record 525 of set 11 | barranca
# Processing record 526 of set 11 | isiolo
# Processing record 527 of set 11 | herat
# Processing record 528 of set 11 | misratah
# Processing record 529 of set 11 | novyy urengoy
# Processing record 530 of set 11 | sisophon
# Processing record 531 of set 11 | vostok
# Processing record 532 of set 11 | mehamn
# Processing record 533 of set 11 | camocim
# Processing record 534 of set 11 | qasigiannguit
# Processing record 535 of set 11 | raudeberg
# Processing record 536 of set 11 | mabay
# Processing record 537 of set 11 | basak
# Processing record 538 of set 11 | teya
# Processing record 539 of set 11 | ponta do sol
# Processing record 540 of set 11 | calvinia
# Processing record 541 of set 11 | klaksvik
# Processing record 542 of set 11 | montes altos
# Processing record 543 of set 11 | college
# Processing record 544 of set 11 | strezhevoy
# Processing record 545 of set 11 | la ronge
# Processing record 546 of set 11 | la cruz
# Processing record 547 of set 11 | mao
# Processing record 548 of set 11 | sakete
# Processing record 549 of set 11 | tarakan
# Processing record 550 of set 11 | imbituba
# Processing record 551 of set 11 | mayo
# Processing record 552 of set 11 | magdalena
# Processing record 553 of set 11 | muli
# Processing record 554 of set 11 | aykhal
# Processing record 555 of set 11 | karratha
# Processing record 556 of set 11 | klyuchi
# Processing record 557 of set 11 | karlskrona
# Processing record 558 of set 11 | chapais
# Processing record 559 of set 11 | jasa tomic
# Processing record 560 of set 11 | pangnirtung
# Processing record 562 of set 12 | veraval
# Processing record 563 of set 12 | samarai
# Processing record 564 of set 12 | sikeston
# Processing record 565 of set 12 | pangody
# Processing record 566 of set 12 | eyl
# Processing record 567 of set 12 | denpasar
# Processing record 568 of set 12 | seymchan
# Processing record 569 of set 12 | rimini
# Processing record 570 of set 12 | solnechnyy
# Processing record 571 of set 12 | papara
# Processing record 572 of set 12 | florianopolis
# Processing record 573 of set 12 | bradenton
# Processing record 574 of set 12 | bundaberg
# Processing record 575 of set 12 | biograd na moru
# Processing record 576 of set 12 | padang
# Processing record 577 of set 12 | codrington
# Processing record 578 of set 12 | ondorhaan
# City not found... Skipping.
# Processing record 579 of set 12 | constantine
# Processing record 580 of set 12 | melfi
# Processing record 581 of set 12 | sabzevar
# Processing record 582 of set 12 | tianpeng
# Processing record 583 of set 12 | qui nhon
# Processing record 584 of set 12 | fuyu
# Processing record 585 of set 12 | vilhena
# Processing record 586 of set 12 | bargal
# City not found... Skipping.
# Processing record 587 of set 12 | piacabucu
# Processing record 588 of set 12 | leningradskiy
# Processing record 589 of set 12 | belaya kholunitsa
# Processing record 590 of set 12 | develi
# Processing record 591 of set 12 | yeppoon
# Processing record 592 of set 12 | huarmey
# Processing record 593 of set 12 | doctor arroyo
# Processing record 594 of set 12 | vincennes
# Processing record 595 of set 12 | labrea
# Processing record 596 of set 12 | saint-augustin
# Processing record 597 of set 12 | sobolevo
# Processing record 598 of set 12 | emporia
# Processing record 599 of set 12 | khor
# Processing record 600 of set 12 | itapetininga
# Processing record 601 of set 12 | mildura
# Processing record 602 of set 12 | rio grande
# Processing record 603 of set 12 | russell
# Processing record 604 of set 12 | road town
# Processing record 605 of set 12 | kiama
# Processing record 606 of set 12 | taoudenni
# Processing record 607 of set 12 | sumbawa
# City not found... Skipping.
# Processing record 608 of set 12 | melipilla
# Processing record 609 of set 12 | ilinskoye-khovanskoye
# Processing record 610 of set 12 | novo aripuana
# Processing record 611 of set 12 | vallenar
# Processing record 613 of set 13 | rockland
# Processing record 614 of set 13 | krotoszyn
# Processing record 615 of set 13 | progreso
# Processing record 616 of set 13 | tasbuget
# City not found... Skipping.
# Processing record 617 of set 13 | xinzhi
# Processing record 618 of set 13 | verkhoyansk
# Processing record 619 of set 13 | shelburne
# Processing record 620 of set 13 | kamenka
# Processing record 621 of set 13 | zharkent
# Processing record 622 of set 13 | dunedin
# Processing record 623 of set 13 | ambodifototra
# City not found... Skipping.
# Processing record 624 of set 13 | kouango
# Processing record 625 of set 13 | isangel
# Processing record 626 of set 13 | guekedou
# City not found... Skipping.
# Processing record 627 of set 13 | mabaruma
# Processing record 628 of set 13 | ilinskiy
# Processing record 629 of set 13 | presidente epitacio
# Processing record 630 of set 13 | wageningen
# Processing record 631 of set 13 | eskasem
# City not found... Skipping.
# Processing record 632 of set 13 | prudentopolis
# Processing record 633 of set 13 | araouane
# Processing record 634 of set 13 | okakarara
# Processing record 635 of set 13 | gibara
# Processing record 636 of set 13 | rock sound
# Processing record 637 of set 13 | hami
# Processing record 638 of set 13 | merauke
# Processing record 639 of set 13 | san cristobal
# Processing record 640 of set 13 | nemuro
# Processing record 641 of set 13 | byron bay
# Processing record 642 of set 13 | divnomorskoye
# Processing record 643 of set 13 | santa maria
# Processing record 644 of set 13 | vestmanna
# Processing record 645 of set 13 | valparaiso
# Processing record 646 of set 13 | hailey
# Processing record 647 of set 13 | mountain home
# Processing record 648 of set 13 | paka
# Processing record 649 of set 13 | grindavik
# Processing record 650 of set 13 | luangwa
# Processing record 651 of set 13 | ozernovskiy
# Processing record 652 of set 13 | adrar
# Processing record 653 of set 13 | pisa
# Processing record 654 of set 13 | sibu
# Processing record 655 of set 13 | camopi
# Processing record 656 of set 13 | rio verde de mato grosso
# Processing record 657 of set 13 | milverton
# Processing record 658 of set 13 | viedma
# Processing record 659 of set 13 | durban
# Processing record 660 of set 13 | san ramon de la nueva oran
# Processing record 661 of set 13 | moranbah
# Processing record 662 of set 13 | itarema
# Processing record 664 of set 14 | lebu
# Processing record 665 of set 14 | mayskiy
# Processing record 666 of set 14 | arlit
# Processing record 667 of set 14 | tecpan
# Processing record 668 of set 14 | tunduru
# City not found... Skipping.
# Processing record 669 of set 14 | oga
# Processing record 670 of set 14 | zhigansk
# Processing record 671 of set 14 | shimoda
# Processing record 672 of set 14 | cuamba
# Processing record 673 of set 14 | antofagasta
# Processing record 674 of set 14 | lapua
# Processing record 675 of set 14 | killarney
# Processing record 676 of set 14 | kosa
# Processing record 677 of set 14 | westerland
# Processing record 678 of set 14 | lasa
# Processing record 679 of set 14 | ekibastuz
# Processing record 680 of set 14 | severnoye
# Processing record 681 of set 14 | velestinon
# City not found... Skipping.
# Processing record 682 of set 14 | eichstatt
# Processing record 683 of set 14 | xiamen
# Processing record 684 of set 14 | plettenberg bay
# Processing record 685 of set 14 | kvarkeno
# Processing record 686 of set 14 | ouargaye
# Processing record 687 of set 14 | cascais
# Processing record 688 of set 14 | marcona
# City not found... Skipping.
# Processing record 689 of set 14 | isetskoye
# Processing record 690 of set 14 | okhotsk
# Processing record 691 of set 14 | goundi
# Processing record 692 of set 14 | apastovo
# Processing record 693 of set 14 | ambon
# Processing record 694 of set 14 | oum hadjer
# Processing record 695 of set 14 | guangyuan
# Processing record 696 of set 14 | calabozo
# Processing record 697 of set 14 | rogers
# Processing record 698 of set 14 | mach
# Processing record 699 of set 14 | sao joao da barra
# Processing record 700 of set 14 | chachapoyas
# Processing record 701 of set 14 | port-de-paix
# City not found... Skipping.
# Processing record 702 of set 14 | tsiroanomandidy
# Processing record 703 of set 14 | omboue
# Processing record 704 of set 14 | niquelandia
# Processing record 705 of set 14 | yakovlevskoye
# Processing record 706 of set 14 | pemberton
# Processing record 707 of set 14 | maloshuyka
# City not found... Skipping.
# Processing record 708 of set 14 | la carolina
# Processing record 709 of set 14 | taburi
# City not found... Skipping.
# Processing record 710 of set 14 | swift current
# Processing record 711 of set 14 | satitoa
# City not found... Skipping.
# Processing record 712 of set 14 | dori
# Processing record 713 of set 14 | kochubey
# Processing record 715 of set 15 | saint-francois
# Processing record 716 of set 15 | chinsali
# Processing record 717 of set 15 | oranjemund
# Processing record 718 of set 15 | bathsheba
# Processing record 719 of set 15 | moiyabana
# City not found... Skipping.
# Processing record 720 of set 15 | virginia beach
# Processing record 721 of set 15 | puerto ayacucho
# Processing record 722 of set 15 | bolshoye sorokino
# City not found... Skipping.
# Processing record 723 of set 15 | omaruru
# Processing record 724 of set 15 | sinnamary
# Processing record 725 of set 15 | millet
# Processing record 726 of set 15 | thinadhoo
# Processing record 727 of set 15 | kolondieba
# Processing record 728 of set 15 | yurla
# Processing record 729 of set 15 | uribia
# Processing record 730 of set 15 | georgiyevka
# Processing record 731 of set 15 | deputatskiy
# Processing record 732 of set 15 | bahia blanca
# Processing record 733 of set 15 | parana
# Processing record 734 of set 15 | daigo
# Processing record 735 of set 15 | buchanan
# Processing record 736 of set 15 | praia da vitoria
# Processing record 737 of set 15 | warmbad
# Processing record 738 of set 15 | san rafael
# Processing record 739 of set 15 | khasan
# Processing record 740 of set 15 | reading
# Processing record 741 of set 15 | pitimbu
# Processing record 742 of set 15 | ouegoa
# Processing record 743 of set 15 | suhbaatar
# Processing record 744 of set 15 | te anau
# Processing record 745 of set 15 | santa cruz del sur
# Processing record 746 of set 15 | zyryanka
# Processing record 747 of set 15 | santa isabel do rio negro
# Processing record 748 of set 15 | kampene
# Processing record 749 of set 15 | youghal
# Processing record 750 of set 15 | briancon
# Processing record 751 of set 15 | chulym
# Processing record 752 of set 15 | kazalinsk
# City not found... Skipping.
# Processing record 753 of set 15 | dongsheng
# Processing record 754 of set 15 | waingapu
# Processing record 755 of set 15 | bang saphan
# Processing record 756 of set 15 | jardim
# Processing record 757 of set 15 | maniitsoq
# Processing record 758 of set 15 | mokhsogollokh
# Processing record 759 of set 15 | sebina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert city_data into pd DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Atuona      PF  -9.8000 -139.0333     80.85        73
# 1              Pakxan      LA  18.3778  103.6601     83.52        59
# 2          Sao Filipe      CV  14.8961  -24.4956     74.86        63
# 3           Huichapan      MX  20.3833  -99.6500     80.60        12
# 4            Khatanga      RU  71.9667  102.5000     19.74        94
# 5              Albany      US  42.6001  -73.9662     64.99        58
# 6           Busselton      AU -33.6500  115.3333     60.01        88
# 7  Tatarskaya Kargala      RU  51.9495   55.1731     37.40        87
# 8             Rikitea      PF -23.1203 -134.9692     78.67        74
# 9            Balkhash      KZ  46.8440   74.9804     37.40        56
#
#    Cloudiness  Wind Speed Current Description
# 0          58       17.20       broken clouds
# 1          84        3.18       broken clouds
# 2           3        9.89           clear sky
# 3           1        8.05           clear sky
# 4         100       15.17          light snow
# 5         100        2.82     overcast clouds
# 6         100        8.01          light rain
# 7           0        8.95           clear sky
# 8           6       11.25           clear sky
# 9           0       20.13           clear sky

# %%
# export DF as a csv file
city_data_df.to_csv("Weather_Database.csv")
